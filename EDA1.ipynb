# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\camil\Documents\Estudio\Seminario\Bases de datos\IPM_2018_2024_CLEAN_CARIBE.csv",sep = ';')

# %%
df.shape
# Out:
# (135835, 28)

# %%
df.head()
# Out:
#    cuartos_dormir  tipo_sanitario  fuente_agua        fex_c  region  \
# 0               2               1            1  384,3281693       1
# 1               2               1            1  297,1724562       1
# 2               2               1            1  274,6401305       1
# 3               1               1            1  397,4006806       1
# 4               1               6            1  19,35421293       1
#
#    departamento  personas  paredes  pisos  alcantarillado  ...  \
# 0             8         2        0      0               0  ...
# 1             8         3        0      0               0  ...
# 2             8         3        0      0               0  ...
# 3             8         2        0      0               0  ...
# 4             8         1        0      1               1  ...
#
#    rezago_escolar  alfabetismo  logro_educativo  hacinamiento   ipm  pobre  \
# 0               0            0                0             0   0,1      0
# ...

# %%
df.columns
# Out:
# Index(['cuartos_dormir', 'tipo_sanitario', 'fuente_agua', 'fex_c', 'region',
#        'departamento', 'personas', 'paredes', 'pisos', 'alcantarillado',
#        'acueducto', 'empleo_formal', 'desempleo_larga_duracion',
#        'barreras_acceso_salud', 'aseguramiento_salud', 'trabajo_infantil',
#        'atencion_integral', 'inasistencia_escolar', 'rezago_escolar',
#        'alfabetismo', 'logro_educativo', 'hacinamiento', 'ipm', 'pobre',
#        'fexp', 'region_nombre', 'departamento_nombre', 'año'],
#       dtype='object')

# %%
df.dtypes
# Out:
# cuartos_dormir               int64
# tipo_sanitario               int64
# fuente_agua                  int64
# fex_c                       object
# region                       int64
# departamento                 int64
# personas                     int64
# paredes                      int64
# pisos                        int64
# alcantarillado               int64
# acueducto                    int64
# empleo_formal                int64
# desempleo_larga_duracion     int64
# barreras_acceso_salud        int64
# aseguramiento_salud          int64
# trabajo_infantil             int64
# atencion_integral            int64
# inasistencia_escolar         int64
# rezago_escolar               int64
# alfabetismo                  int64
# logro_educativo              int64
# hacinamiento                 int64
# ipm                         object
# pobre                        int64
# fexp                        object
# region_nombre               object
# departamento_nombre         object
# ...

# %%
df.describe()
# Out:
#        cuartos_dormir  tipo_sanitario    fuente_agua    region   departamento  \
# count   135835.000000   135835.000000  135835.000000  135835.0  135835.000000
# mean         1.755026        2.239923       2.554835       1.0      31.565031
# std          0.770890        1.719451       2.434362       0.0      20.795113
# min          1.000000        1.000000       1.000000       1.0       8.000000
# 25%          1.000000        1.000000       1.000000       1.0      13.000000
# 50%          2.000000        2.000000       1.000000       1.0      23.000000
# 75%          2.000000        2.000000       4.000000       1.0      47.000000
# max          9.000000        6.000000      10.000000       1.0      70.000000
#
#             personas        paredes          pisos  alcantarillado  \
# count  135835.000000  135835.000000  135835.000000   135835.000000
# mean        3.343387       0.036809       0.225030        0.267935
# ...

# %%
df.describe(include= 'object')
# Out:
#               fex_c     ipm         fexp region_nombre departamento_nombre
# count        135835  135835       135835        135835              135835
# unique       101622      75       103121             1                   7
# top     19,35421293     0,1  19,35421293        Caribe             BOLIVAR
# freq            104   16534          104        135835               21511

# %% [markdown]
# - Para el IPM observamos un total de 75 clasificasiones diferentes
# - Se divide en 7 departamentos en los que se incluye: 'ATLANTICO' 'CORDOBA' 'MAGDALENA' 'SUCRE' 'BOLIVAR' 'LA GUAJIRA' 'CESAR'. Cabe aclarar que 'San Andrés y Providencia no se encuentra en el dataset del DANE como región caribe.
# - El departamento con más representación dentro del dataset es el departamento de bolivar

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21492\2639561883.py in ?()
# ----> 1 df.REGION_NOMBRE.head(10)
#
# c:\Users\camil\anaconda3\envs\mlp\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'REGION_NOMBRE'

# %%
print(df.departamento_nombre.unique())
# Out:
# ['ATLANTICO' 'CORDOBA' 'MAGDALENA' 'SUCRE' 'BOLIVAR' 'LA GUAJIRA' 'CESAR']
